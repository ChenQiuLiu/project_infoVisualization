# %%
# -*- coding: utf-8 -*-
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import *
import seaborn as sns
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.patches import ConnectionPatch

data = pd.read_csv("./project1_dataset.csv")

# %% [markdown]
# # All Functions

# %%
def dataGeneMLBubble(dataframe, xname, yname, radius = None, mean = False):
    """
    generate data
    
    @parameter dataframe:        dataframe
    @parameter xnmae:            the feature in dataframe
    @parameter yname:            the feature in dataframe
    @parameter radius:           the feature in dataframe
    result like this :[ [            "SVM"                                               ,           "GNB"               ],
                      [ ["float 64"  ,  "int 32"]                                         ,  [ "float 64"  ,    "int 32"]], 
                      [ [[6]<--if mean is True ,  [4,7,8,9,3 ] <--if mean is false]       ,  [ [5,5,7,9,6] , [4,7,8,9,3 ]]] 
                                                ]
    """
    result = [[],[],[]]
    for w in list(dataframe[xname].value_counts().index):
        result[0].append(w)
        result[1].append([])
        result[2].append([])
    result[0] = sorted(result[0])
    for i in list(dataframe[xname].value_counts().index):
        key = dataframe[dataframe[xname] == i]
        for j in list(key[yname].value_counts().index):
            result[1][result[0].index(i)].append(j)
            key1 = key[key[yname] == j]
            """make sure what you want: mean? or the whole data"""
            if mean:
                result[2][result[0].index(i)].append(np.mean(key1[radius]).round(2))
            else:
                result[2][result[0].index(i)].append(list(key1[radius].round(2)))
    return result

def getfirst(ls):
    return ls[0]

def plotGTwoVar(ax, data,tpe = None ,xlabel = None ,ylabel = None, legend = None, area_annotion = None, area = False, title = None):
    """
    draw line chart
    @paramteer       ax:               the position where you draw;
    @paramteer       data: 
                                       the data[0] is a list : The independent variables;
                                       the data[1] is a list : The dependent variable;
    @parameter       tpe:              which graph tpe you want? scatter(default) or bar?
    @parameter       xlabel:           the label of axis x;
    @parameter       ylabel:           the label of axis y;
    @parameter       legend:           what will you show legend of this graph?
    @parameter       area:             A confidence interval
    @parameter       area_annotion:    The notation of confidence intervals.
    @parameter       title:            The title of ax.
    """
    dic = {key:[] for key in set(list(data[0]))}
    ls = []
    for i in range(len(list(data[0]))):
        dic[data[0].iloc[i]].append(data[1].iloc[i])
    for i in dic.keys():
        if mean(dic[i]) - 3*np.std(dic[i]) < 0:
            key = 0
        else:
            key = mean(dic[i]) - 3*np.std(dic[i])
        ls.append((i, mean(dic[i]),mean(dic[i]) + 3*np.std(dic[i]), key))
    ls.sort(key = getfirst)
    x = [i[0] for i in ls]
    y = [i[1] for i in ls]
    shadow_up = [i[2] for i in ls]
    shadow_down = [i[3] for i in ls]

    if xlabel != None:
        ax.set_xlabel(xlabel)
    if ylabel != None:
        ax.set_ylabel(ylabel)
    if title != None:
        ax.set_title(title)
        
    if area:
        for i in range(len(x)):
            ax.fill_between(x, shadow_down, shadow_up,alpha = 0.05, color = 'gray')
        ax.annotate(area_annotion,
                    xy=(x[1], shadow_up[1]),
                    xytext=(x[1], shadow_up[1]*1.5),
                    xycoords='data',
                    arrowprops=dict(facecolor='yellow', shrink=0.05))
         
    if tpe == None or tpe.lower() == "scatter":
        for i in range(len(x)):
            ax.plot(x[i], y[i], 'o',color = 'r' ,alpha = 0.4)
        ax.plot(x, y,label = legend, alpha = 0.9)
    elif tpe.lower() == "bar":
        for i in range(len(x)):
            ax.bar(x[i], y[i], alpha = 0.4)
    

    ax.set_ylim(0)
    if ax.set_ylim()[1] <max(y):
        ax.set_ylim(ymin = 0,ymax = (max(y) + 0.2*max(y)))
    if legend != None:
        ax.legend()
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    

def bubbleG(ax, data, xlabel = None, ylabel = None, anno_max_and_min = True, title = None, times = 1, totaltitle = None):
    """
    draw bubble chart
    
    @para ax: the position where you draw;
    @para data: three value:
                            data[0]: x
                            data[1]: y
                            data[2]: radius
                            example about data: [ [            "SVM"             ,           "GNB"            ],
                                                  [ ["float 64"  ,  "int 32"]    ,[ "float 64"  , "int 32"]   ], 
                                                  [ [  6         ,       4   ] ,  [       5     ,    4        ] 
                                                ]
    """
    colors = np.random.rand(len(data[0])) 
    for i in range(len(data[0])):
        for j in range(len(data[1][i])):
            col = []
            for algo in range(len(data[0])):
                for yn in range(len(data[1][algo])):
                    if yn == j:
                        col.append(data[2][algo][yn])
            if data[2][i][j] == max(data[2][i]) and (data[2][i][j] == max(col)):
                axn = ax.scatter(data[1][i][j],data[0][i],s=data[2][i][j]*200*times,marker = "p",alpha=0.5,c = "red")
            elif data[2][i][j] == min(data[2][i]) and (data[2][i][j] == min(col)):
                axn = ax.scatter(data[1][i][j],data[0][i],s=data[2][i][j]*200*times,marker = "^",alpha=0.5,c = "green")
            elif data[2][i][j] == max(data[2][i])and (data[2][i][j] != max(col)):
                axn = ax.scatter(data[1][i][j],data[0][i],s=data[2][i][j]*200*times,alpha=0.5,c = "red")
            elif data[2][i][j] == min(data[2][i])and (data[2][i][j] != min(col)):
                axn = ax.scatter(data[1][i][j],data[0][i],s=data[2][i][j]*200*times,alpha=0.5,c = "green")
            elif data[2][i][j] != min(data[2][i])and (data[2][i][j] == min(col)):
                axn = ax.scatter(data[1][i][j],data[0][i],s=data[2][i][j]*200*times,marker = "^",alpha=0.5,c = "blue")
            elif data[2][i][j] != max(data[2][i])and (data[2][i][j] == max(col)):
                axn = ax.scatter(data[1][i][j],data[0][i],s=data[2][i][j]*200*times,marker = "p",alpha=0.5,c = "blue")
            else:
                axn = ax.scatter(data[1][i][j],data[0][i],s=data[2][i][j]*200*times,alpha=0.5,c = "gray")
    if totaltitle != None:
        fig.suptitle(totaltitle,fontsize = 20)
    if title != None:
        ax.set_title(title)
    if xlabel != None:
        ax.set_xlabel(xlabel)
    if ylabel != None:
        ax.set_ylabel(ylabel)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.xticks(fontproperties = 'Times New Roman', size = 10)
    plt.yticks(fontproperties = 'Times New Roman', size = 10)
    plt.subplots_adjust(hspace=0.15, wspace=0.3)

# %% [markdown]
# # REQUIREMENT 2

# %%
#Data preparation
df21 = data[data["algorithm"] == "SVM"]
fig, ax = plt.subplots(1,1,figsize = (10,5))
a = df21["no_features"][data["RQ"] == 2.2]
b = df21["train_energy(J)"][data["RQ"] == 2.2]
plotGTwoVar(ax, [a, b] ,xlabel = 'SVM_no_features', ylabel = 'SVM_train_eneigy', legend = 'Average broken line for every five experiments', area = True, area_annotion = "gray confidence interval: 99%",title = "SVM:no_features effect on train_energy(J)")

# %% [markdown]
# # REQUIREMENT 3

# %% [markdown]
# For the third requirement, we use the bubble diagram to answer.
#
# 1.There are two functions used.
#
#
# --The first is the function that generates the data-------dataGeneMLBubble(dataframe, xname, yname, radius = None, mean = False)
#
#
# --The second is the function that draws the graph---------bubbleG(ax, data, xlabel = None, ylabel = None, anno_max_and_min = True, title = None, times = 1, totaltitle = None).
#
# o In terms of the image, the Y-axis is set as the algorithm, the X-axis is a corresponding variable, and the size of the bubble.
#
# o represents the average value of train energy obtained through five experiments under this experimental condition.
#
# o For horizontal comparison, we use color to divide, red is the maximum value, green is the minimum value, and the rest is blue.
#
# o For vertical comparison, we used shape division, with pentagram being the maximum, triangle being the minimum, and the rest being circle.

# %%
#We set up two rows and three columns, with the first row of three diagrams showing all the data.
#The second line is to show the lower-value data.
data_1 = data[data["RQ"] == 2.1]
data_2 = data[data["RQ"] == 2.2]
dataset_1 = dataGeneMLBubble(data_1, "algorithm", "no_datapoints", "train_energy(J)",mean = True)
dataset_2 = dataGeneMLBubble(data_2, "algorithm", "no_features", "train_energy(J)",mean = True)
dataset_3 = dataGeneMLBubble(data, "algorithm", "datatype", "train_energy(J)",mean = True)
fig, ax = plt.subplots(2,3,figsize = (21,10))
#Let me draw all the data
bubbleG(ax[0][0], data = dataset_3,ylabel = "Algorithm", 
        totaltitle = "for each machine learning algorithm, how no_datapoints, no_features, and datatype affect energy consumption")
bubbleG(ax[0][1], data = dataset_2)
bubbleG(ax[0][2], data = dataset_1)
#lower data 
lower = ["Multinomial NB", "KNN", "Decision Tree"]
lower_3 = [[],[],[]]
lower_2 = [[],[],[]]
lower_1 = [[],[],[]]
for i in lower:
    lower_3[0].append(i)
    index = dataset_3[0].index(i)
    lower_3[1].append(dataset_3[1][index])
    lower_3[2].append(dataset_3[2][index])
    lower_2[0].append(i)
    index = dataset_2[0].index(i)
    lower_2[1].append(dataset_2[1][index])
    lower_2[2].append(dataset_2[2][index])
    lower_1[0].append(i)
    index = dataset_1[0].index(i)
    lower_1[1].append(dataset_1[1][index])
    lower_1[2].append(dataset_1[2][index])
#since number is low, so we make it bigger. times = 20
bubbleG(ax[1][0], data = lower_3, times = 20,xlabel = "data type",ylabel = "Algorithm")
bubbleG(ax[1][1], data = lower_2, times = 20,xlabel = "features")
bubbleG(ax[1][2], data = lower_1, times = 20,xlabel = "data points")
print("guideline: ")
print("1. color  :The color represents only the description of the data in each row. Red represents the maximum value of the row, green represents the minimum value of the row, and blue represents the middle value of the row.")
print("2.  type  :The shape only represents the description of the data in each column, the five-pointed star represents the maximum value of the column, the triangle represents the minimum value of the column, and the gray represents the middle value of the column.")
print("3.  train energy: The radius of the outer circle of each shape represents the average train energy of every five experiments under experimental conditions at this position.")
print("4.  two row:  the upper row's graph present whole data. Some small data in rwo one show in row two under the same column")
# Out:
# guideline:
# 1. color  :The color represents only the description of the data in each row. Red represents the maximum value of the row, green represents the minimum value of the row, and blue represents the middle value of the row.
# 2.  type  :The shape only represents the description of the data in each column, the five-pointed star represents the maximum value of the column, the triangle represents the minimum value of the column, and the gray represents the middle value of the column.
# 3.  train energy: The radius of the outer circle of each shape represents the average train energy of every five experiments under experimental conditions at this position.
# 4.  two row:  the upper row's graph present whole data. Some small data in rwo one show in row two under the same column
